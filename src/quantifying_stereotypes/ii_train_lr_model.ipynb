# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

pd.set_option('display.max_colwidth', None)

# %%
input_df = pd.read_csv('stereotype_train.csv')
print(input_df.shape)
input_df.head(2)
# Out:
# (559, 15)
#   has_category_label                 full_label beliefs_expectancies  \
# 0                yes          Bangladesh people                  yes
# 1                yes  My friend from bangladesh                  yes
#
#                                information behavior_features_traits  \
# 0  are lous and quarell they are not quite                      yes
# 1                             is very poor                      yes
#
#   stereotype      target_type connotation gram_form   ling_form  \
# 0        yes   generic target    negative      noun     generic
# 1        yes  specific target     neutral      noun  individual
#
#                   situation situation_evaluation generalization  \
# 0  enduring characteristics             negative       abstract
# 1  enduring characteristics             negative       abstract
#
#                                             sentence       bws
# 0  Bangladesh people are lous and quarell they ar...  0.145045
# 1            My friend from bangladesh is very poor.  0.130204

# %% [markdown]
# Features for scsc:
# - `generalization_category_label` = [`ling_form`]_[`target_type`]
# - `connotation` = `connotation`
# - `gram_form` = `gram_form`
# - `generalization_situation` = [`situation`]_[`generalization`]
# - `situation_evaluation` = `situation_evaluation`

# %%
input_df['generalisation_category_label'] = input_df['ling_form'].astype(str) + '_' + input_df['target_type'].astype(str)
input_df.drop(columns=['ling_form', 'target_type'], inplace=True)

input_df['generalisation_situation'] = input_df['situation'].astype(str) + '_' + input_df['generalization'].astype(str)
input_df.drop(columns=['situation', 'generalization'], inplace=True)

# %%
cat_cols = [
    'generalisation_category_label', 
    'connotation', 
    'gram_form', 
    'generalisation_situation', 
    'situation_evaluation'
]

input_df.drop(columns=[x for x in input_df.columns if x not in cat_cols + ['bws']], inplace=True)

# %%
input_df.sample(3)
# Out:
#     connotation gram_form situation_evaluation       bws  \
# 128     neutral      noun             positive  0.356921
# 151     neutral      noun       not-applicable  0.017413
# 519     neutral      noun             positive  0.063068
#
#     generalisation_category_label           generalisation_situation
# 128        generic_generic target  enduring characteristics_abstract
# 151         subset_generic target      not-applicable_not-applicable
# 519        subset_specific target     situational behaviour_concrete

# %%
encoder = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cat_cols)
    ],
    remainder='passthrough'
)

# %%
bins = pd.cut(input_df['bws'], bins=3, labels=False)

# %%
train_df, test_df = train_test_split(input_df, test_size=0.05, random_state=88, stratify=bins)

# %%
print(f"Train Mean: {train_df['bws'].mean():.2f}")
print(f"Test Mean: {test_df['bws'].mean():.2f}")
# Out:
# Train Mean: 0.12
# Test Mean: 0.12

# %%
model_pipeline = Pipeline(steps=[
    ('encoder', encoder),
    ('model', LinearRegression())
])

# %%
X_train = train_df.drop('bws', axis=1)
y_train = train_df['bws']

model_pipeline.fit(X_train, y_train)

print("Model training complete!")
# Out:
# Model training complete!

# %%
from sklearn.metrics import mean_absolute_error

# Prepare test data
X_test = test_df.drop('bws', axis=1)
y_test = test_df['bws']

# Predict
predictions = model_pipeline.predict(X_test)

# Evaluate
print(f"MAE: {mean_absolute_error(y_test, predictions):.2f}")
# Out:
# MAE: 0.09

# %%
import joblib
from pathlib import Path

Path('model').mkdir(exist_ok=True)

joblib.dump(model_pipeline.named_steps['encoder'], 'model/lr_scsc_encoder.joblib')
joblib.dump(model_pipeline.named_steps['model'], 'model/lr_scsc_model.joblib')
# Out:
# ['model/lr_scsc_model.joblib']

# %%
predictions = model_pipeline.predict(input_df)

# %%
input_df = pd.read_csv('stereotype_train.csv')
input_df['generalisation_category_label'] = input_df['ling_form'].astype(str) + '_' + input_df['target_type'].astype(str)
input_df.drop(columns=['ling_form', 'target_type'], inplace=True)

input_df['generalisation_situation'] = input_df['situation'].astype(str) + '_' + input_df['generalization'].astype(str)
input_df.drop(columns=['situation', 'generalization'], inplace=True)

# %%
input_df.drop(columns=[x for x in input_df.columns if x not in cat_cols + ['sentence']], inplace=True)
input_df.to_csv('stereotype_train_scored.csv', index=False)

# %%
all_res = np.array(predictions).flatten()

result_df = pd.read_csv('stereotype_train_scored.csv', index_col=False, usecols=['sentence'] + cat_cols)
result_df = result_df.reindex(columns=cat_cols + ['sentence'])

result_df['scsc_score'] = all_res
result_df.sample(10)
# Out:
#      generalisation_category_label     connotation       gram_form  \
# 486         generic_generic target        negative            noun
# 517         generic_generic target         neutral            noun
# 306         generic_generic target         neutral            noun
# 222         subset_specific target         neutral            noun
# 22          generic_generic target         neutral           other
# 232  not-applicable_not-applicable  not-applicable  not-applicable
# 167         generic_generic target         neutral            noun
# 336         generic_generic target         neutral            noun
# 505          subset_generic target         neutral           other
# 551         generic_generic target         neutral            noun
#
#               generalisation_situation situation_evaluation  \
# 486  enduring characteristics_abstract             negative
# 517  enduring characteristics_abstract              neutral
# 306  enduring characteristics_abstract             positive
# 222  enduring characteristics_abstract             positive
# 22   enduring characteristics_abstract             negative
# 232      not-applicable_not-applicable       not-applicable
# 167     situational behaviour_abstract             negative
# 336  enduring characteristics_abstract             negative
# 505               other_not-applicable       not-applicable
# 551  enduring characteristics_abstract             negative
#
#                                               sentence  scsc_score
# 486  Jewish people are conspiring against everyone ...    0.309197
# 517        Muslims believe in the importance of hijab.    0.098682
# 306  A schoolboy should be young and have a good time.   -0.048075
# 222  The oppressed women of somalia are the bedrock...   -0.111200
# 22   He couldn't understand how someone could be Ch...    0.394967
# 232  Discussions on the syria subreddit are always ...    0.022226
# 167  The police have always hated the blacks in thi...    0.345384
# 336       women always complain when they are pregnant    0.272065
# 505  I went to live next to a mosque, and the place...    0.303722
# 551                 Brahmins are very arrogant people.    0.272065

# %%
result_df.describe()
# Out:
#        scsc_score
# count  559.000000
# mean     0.123602
# std      0.162026
# min     -0.324679
# 25%      0.022226
# 50%      0.200853
# 75%      0.264118
# max      0.413050

# %%
result_df['scsc_score'] = (result_df['scsc_score'] - result_df['scsc_score'].min()) / (result_df['scsc_score'].max() - result_df['scsc_score'].min())
result_df.where((result_df['scsc_score'] > 0.60) & (result_df['scsc_score'] < 0.65)).dropna().sort_values('scsc_score', ascending=True)
# Out:
#     generalisation_category_label connotation gram_form  \
# 35         generic_generic target     neutral   pronoun
# 18         subset_specific target     neutral      noun
# 322        subset_specific target     neutral      noun
# 337    individual_specific target    negative      noun
# 151         subset_generic target     neutral      noun
# 114         subset_generic target     neutral      noun
# 335         subset_generic target     neutral      noun
# 154    individual_specific target    negative      noun
# 430    individual_specific target    negative      noun
# 460    individual_specific target    negative      noun
# 488    individual_specific target    negative      noun
#
#               generalisation_situation situation_evaluation  \
# 35   enduring characteristics_abstract             positive
# 18       not-applicable_not-applicable       not-applicable
# 322      not-applicable_not-applicable       not-applicable
# 337     situational behaviour_concrete             negative
# 151      not-applicable_not-applicable       not-applicable
# 114      not-applicable_not-applicable       not-applicable
# 335      not-applicable_not-applicable       not-applicable
# 154  enduring characteristics_abstract             negative
# 430  enduring characteristics_abstract             negative
# 460  enduring characteristics_abstract             negative
# 488  enduring characteristics_abstract             negative
#
#                                                                      sentence  \
# 35                       He was black so building muscle comes easy for them.
# 18                    I thought this was too much coming from a Chinese game.
# 322                     I was so surprised that the new kid was a trans girl.
# 337                I called them a dumb female for getting us in to the mess.
# 151        John wasn't available for the meeting in regards to black workers.
# 114                                                Morocco is a black country
# 335                       Joe then spent the money on a bunch of prostitutes.
# 154              Ally was a black girl, slutty as hell, interested in anyone.
# 430                             Her husband claims she is an ignorant female.
# 460  Joan was a Wiccan, she couldn't escape her true nature and dark motives.
# 488       The guide was a Muslim, they lie, I don't believe what he's saying.
#
#      scsc_score
# 35     0.601282
# 18     0.621740
# 322    0.621740
# 337    0.637013
# 151    0.644919
# 114    0.644919
# 335    0.644919
# 154    0.647786
# 430    0.647786
# 460    0.647786
# 488    0.647786

# %%
result_df['stereotype'] = result_df['scsc_score'].apply(lambda x: True if x >= 0.608 else False)
print(result_df.describe())
result_df.sort_values('scsc_score', ascending=False).head(10)
# Out:
#        scsc_score
# count  559.000000
# mean     0.607651
# std      0.219628
# min      0.000000
# 25%      0.470234
# 50%      0.712364
# 75%      0.798120
# max      1.000000
#     generalisation_category_label connotation gram_form  \
# 4          subset_specific target    negative   pronoun
# 22         generic_generic target     neutral     other
# 499         subset_generic target    negative     other
# 30         subset_specific target    negative     other
# 167        generic_generic target     neutral      noun
# 91         generic_generic target     neutral      noun
# 513        subset_specific target     neutral     other
# 87     individual_specific target    negative   pronoun
# 62     individual_specific target     neutral     other
# 495        generic_generic target    negative      noun
#
#               generalisation_situation situation_evaluation  \
# 4    enduring characteristics_abstract             negative
# 22   enduring characteristics_abstract             negative
# 499  enduring characteristics_abstract             negative
# 30      situational behaviour_concrete             negative
# 167     situational behaviour_abstract             negative
# 91                      other_concrete       not-applicable
# 513     situational behaviour_concrete             negative
# 87   enduring characteristics_concrete             negative
# 62      situational behaviour_abstract             negative
# 495  enduring characteristics_abstract             negative
#
#                                                                                  sentence  \
# 4                                       They are from bangladesh so they must be stoners.
# 22                      He couldn't understand how someone could be Chinese and yet dumb.
# 499                   Anybody who reads the Quran is not a trustworthy person in my book.
# 30   I saw the look on her face, but couldn't interpret it due to her Asian squinty eyes.
# 167                         The police have always hated the blacks in this neighborhood.
# 91                                                      The black people are from crimean
# 513                Clients seemed to hate the face time though, due to his Muslim attire.
# 87                           Kelsi likes chicken because she is black and has monkey lips
# 62                          If you were black, that choice would be made for you already.
# 495                                    Catholics love quoting the selfcontradicting bible
#
#      scsc_score  stereotype
# 4      1.000000        True
# 22     0.975488        True
# 499    0.963433        True
# 30     0.929482        True
# 167    0.908278        True
# 91     0.881779        True
# 513    0.879148        True
# 87     0.870602        True
# 62     0.863433        True
# 495    0.859226        True

# %%
result_df.to_csv("../stereotype_scored.csv", index=False)
