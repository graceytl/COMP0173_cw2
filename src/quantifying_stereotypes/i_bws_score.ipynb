# %%
import pandas as pd

# %%
train = pd.read_csv('../..//quantifying-stereotypes-in-language/data/train.csv', index_col=False, usecols=[0, 2], header=None)
val = pd.read_csv('../../quantifying-stereotypes-in-language/data/val.csv', index_col=False, usecols=[0, 2], header=None)
test = pd.read_csv('../../quantifying-stereotypes-in-language/data/test.csv', index_col=False, usecols=[0, 2], header=None)

# %%
print(len(train) + len(val) +len(test))
# Out:
# 2976

# %%
headers = ['sentence', 'bws']

all_scores = pd.concat([train, val, test], ignore_index=True)
all_scores.columns = headers

print(all_scores.shape)
all_scores.sample(5)
# Out:
# (2976, 2)
#                                                sentence       bws
# 256   Ecuador is known for its hot weather during th... -0.349519
# 965          Joe was black and his hair was hard to cut  0.076572
# 315   When i think of a producer, it is someone who ...  0.203877
# 1535  The good bible was very prevalent in the culture. -0.088952
# 1049  Jack declined to have sex with the ex as he va... -0.188586

# %%
stereotype_df = pd.read_csv('../dataset_gen/stereotype_indicators.csv')
stereotype_df['sentence'] = stereotype_df['text']
stereotype_df.drop(columns=['text'], inplace=True)

print(stereotype_df.shape)
stereotype_df['sentence'].sample(5)
# Out:
# (3983, 14)
# 1660          He was quite the manly man, at his stature.
# 228        lots of people in Pakistan it can be dangerous
# 3298                           most lesbians are a phase.
# 865     I don't know much about the country of Romania...
# 1232    Discussions on the syria subreddit are always ...
# Name: sentence, dtype: object

# %%
# Clean the sentences in both dataframes to find matches by stripping whitespace, removing punctuation, and converting to lowercase
stereotype_df['cleaned_sentence'] = stereotype_df['sentence'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)
all_scores['cleaned_sentence'] = all_scores['sentence'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)

# %%
mask = all_scores['sentence'].isin(stereotype_df['sentence'])
filtered_scores = all_scores[mask]
print(filtered_scores.shape)
filtered_scores.sample(5)
# Out:
# (565, 3)
#                                                sentence       bws  \
# 1151  Adrin couldn't afford a cloak or hat as he was...  0.359610
# 1842  One day Joanne was having fun, but a black man...  0.220878
# 132   Joan was a Wiccan, she couldn't escape her tru...  0.282880
# 1051                         Women are naturally timid.  0.278737
# 1280  Gentlemen are respectful men to women their da...  0.074058
#
#                                        cleaned_sentence
# 1151  adrin couldnt afford a cloak or hat as he was ...
# 1842  one day joanne was having fun but a black man ...
# 132   joan was a wiccan she couldnt escape her true ...
# 1051                          women are naturally timid
# 1280  gentlemen are respectful men to women their da...

# %%
mask = all_scores['cleaned_sentence'].isin(stereotype_df['cleaned_sentence'])
cleaned_matches = all_scores[mask]
print(cleaned_matches.shape)
cleaned_matches.sample(5)
# Out:
# (565, 3)
#                                                sentence       bws  \
# 2032  the angry jew was flinging gold coins from is ...  0.359790
# 1427  The muslim following has often been described ...  0.146305
# 2202  He couldn't figure out the issue with the rope...  0.200322
# 438   He was black so building muscle comes easy for...  0.332155
# 1457  Julius was surprised to see that the Jewish la... -0.025062
#
#                                        cleaned_sentence
# 2032  the angry jew was flinging gold coins from is ...
# 1427  the muslim following has often been described ...
# 2202  he couldnt figure out the issue with the rope ...
# 438   he was black so building muscle comes easy for...
# 1457  julius was surprised to see that the jewish la...

# %%
print(f"Number of matches without cleaning: {len(filtered_scores)}")
print(f"Number of matches with cleaning: {len(cleaned_matches)}")
# Out:
# Number of matches without cleaning: 565
# Number of matches with cleaning: 565

# %%
pd.set_option('display.max_colwidth', None)

# %%
bws_scores = filtered_scores.drop(columns=['cleaned_sentence'])
bws_scores.shape
# Out:
# (565, 2)

# %%
stereotype_df.drop(columns=['cleaned_sentence'], inplace=True)

# %%
unique_stereotype_df = stereotype_df.drop_duplicates(subset=['sentence'], keep='first')
unique_bws_scores = bws_scores.drop_duplicates(subset=['sentence'], keep='first')
print(stereotype_df.shape)
print(unique_stereotype_df.shape)
print(bws_scores.shape)
print(unique_bws_scores.shape)
# Out:
# (3983, 14)
# (3957, 14)
# (565, 2)
# (559, 2)

# %%
unique_stereotype_df = pd.merge(unique_stereotype_df, unique_bws_scores, on='sentence', how='left')
print(unique_stereotype_df.shape)
unique_stereotype_df.sample(5)
# Out:
# (3957, 15)
#      has_category_label             full_label beliefs_expectancies  \
# 3595                yes         Brahmin people                  yes
# 939                 yes  The Nigerian criminal                  yes
# 3170                yes           LGBTQ people                  yes
# 484                 yes           black people                  yes
# 3618                yes                 muslim                  yes
#
#                  information behavior_features_traits stereotype  \
# 3595     are seen as ancient                      yes        yes
# 939   was arrested for fraud                      yes        yes
# 3170          are contagious                      yes        yes
# 484       were good swimmers                      yes        yes
# 3618          not-applicable                      yes        yes
#
#           target_type connotation gram_form ling_form  \
# 3595   generic target     neutral      noun   generic
# 939   specific target    negative      noun    subset
# 3170   generic target     neutral      noun   generic
# 484    generic target     neutral      noun   generic
# 3618   generic target     neutral      noun   generic
#
#                      situation situation_evaluation  generalization  \
# 3595  enduring characteristics             positive        abstract
# 939      situational behaviour             negative        concrete
# 3170  enduring characteristics             negative        abstract
# 484   enduring characteristics             negative        abstract
# 3618            not-applicable       not-applicable  not-applicable
#
#                                             sentence       bws
# 3595             Brahmin people are seen as ancient. -0.006923
# 939     The Nigerian criminal was arrested for fraud       NaN
# 3170     we expect that LGBTQ people are contagious.       NaN
# 484   I didn't think black people were good swimmers  0.276218
# 3618   Jihad is associated with the religion muslim.       NaN

# %%
print(unique_stereotype_df['bws'].isna().sum())
print(unique_stereotype_df.shape)
# Out:
# 3398
# (3957, 15)

# %%
lr_df = unique_stereotype_df.copy().dropna(subset=['bws'])
print(lr_df.shape)
lr_df.head(5)
# Out:
# (559, 15)
#    has_category_label                 full_label beliefs_expectancies  \
# 7                 yes          Bangladesh people                  yes
# 12                yes  My friend from bangladesh                  yes
# 13                yes       people in bangladesh                  yes
# 15                 no             not-applicable                  yes
# 16                yes                       They                  yes
#
#                                 information behavior_features_traits  \
# 7   are lous and quarell they are not quite                      yes
# 12                             is very poor                      yes
# 13                               are indian                      yes
# 15                           not-applicable                       no
# 16                  so they must be stoners                      yes
#
#    stereotype      target_type     connotation       gram_form  \
# 7         yes   generic target        negative            noun
# 12        yes  specific target         neutral            noun
# 13        yes   generic target         neutral            noun
# 15        yes   not-applicable  not-applicable  not-applicable
# 16        yes  specific target        negative         pronoun
#
#          ling_form                 situation situation_evaluation  \
# 7          generic  enduring characteristics             negative
# 12      individual  enduring characteristics             negative
# 13         generic                     other       not-applicable
# 15  not-applicable            not-applicable       not-applicable
# 16          subset  enduring characteristics             negative
#
#     generalization  \
# 7         abstract
# 12        abstract
# 13  not-applicable
# 15  not-applicable
# 16        abstract
#
#                                                       sentence       bws
# 7   Bangladesh people are lous and quarell they are not quite.  0.145045
# 12                     My friend from bangladesh is very poor.  0.130204
# 13                        Most people in bangladesh are indian  0.064644
# 15                        I think bangladesh is a poor country -0.092413
# 16           They are from bangladesh so they must be stoners.  0.256160

# %%
lr_df.to_csv('stereotype_train.csv', index=False)

# %% [markdown]
# # DO not run

# %%
# rest_df = unique_stereotype_df.copy()[unique_stereotype_df['bws'].isna()]
# rest_df.drop(columns=['bws'], inplace=True)
# print(rest_df.shape)
# rest_df.head(3)

# %%
# rest_df.to_csv('stereotype_predict.csv', index=False)
