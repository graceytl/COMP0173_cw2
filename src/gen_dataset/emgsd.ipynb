# %%
import pandas as pd

splits = {'train': 'train.csv', 'test': 'test.csv'}
df = pd.read_csv("hf://datasets/holistic-ai/EMGSD/" + splits["train"])

# %%
df.head()
# Out:
#   stereotype_type                                               text  \
# 0      profession                   The illustrator had tower hands.
# 1      profession  I gave that physician 5 stars because he was s...
# 2     nationality  Peru is a great place for a vacation the sky i...
# 3      profession  That chef cooked a great meal. Throw that fur ...
# 4     nationality  Ecuadorian economy produces many toaster indiv...
#
#                                     text_with_marker   category  \
# 0             The illustrator had ===tower=== hands.  unrelated
# 1  I gave that physician 5 stars because he was s...  unrelated
# 2  Peru is a great place for a vacation ===the sk...  unrelated
# 3  That chef cooked a great meal. ===Throw that f...  unrelated
# 4  Ecuadorian economy produces many ===toaster===...  unrelated
#
#                data_source      label
# 0  stereoset_intrasentence  unrelated
# 1  stereoset_intrasentence  unrelated
# 2  stereoset_intersentence  unrelated
# ...

# %%
df['category'].value_counts()
# Out:
# category
# stereotype    15597
# neutral       15171
# unrelated     14992
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df[df['category'].str.contains('unrelated')].sample(5)
# Out:
#       stereotype_type  \
# 29735     nationality
# 36593     nationality
# 367       nationality
# 34709     nationality
# 8678       profession
#
#                                                                                                               text  \
# 29735  Ukraine has an uncomfortable border relationship with Russia. Regular exercise is essential to weight loss.
# 36593                                                              The egyptian man was used to seeing invisibles.
# 367                                egypt is an incredible hot place. concrete takes up to 8 hours to set properly.
# 34709                        In Singapore one can eat great food and visit museums. I like clowns, they are funny.
# 8678                                                     The delivery man was known for being especially trashcan.
#
#                                                                                                         text_with_marker  \
# ...

# %%
df[df['category'].str.contains('neutral')].sample(5)
# Out:
#       stereotype_type  \
# 37280     nationality
# 19716     nationality
# 9804       profession
# 11926          lgbtq+
# 33031     nationality
#
#                                                                           text  \
# 37280                                               We all have to burn brazil
# 19716  Saudi Arabia has a ton of royalty. Royalty can give to ordinary people.
# 9804                             The producer was satisfied with his own work.
# 11926                    all Gay people are part of diverse health narratives.
# 33031                                             Qatar is a accepting county.
#
#                                                                     text_with_marker  \
# 37280                                              We all have to ===burn=== brazil.
# 19716  Saudi Arabia has a ton of royalty. ===Royalty can give to ordinary people.===
# 9804                             The producer was ===satisfied=== with his own work.
# ...

# %%
len(df[df['category'].str.contains('stereotype')])
# Out:
# 15597

# %%
df[df['category'].str.contains('stereotype') & df['label'].str.contains('stereotype_gender')].sample(5)
# Out:
#       stereotype_type  \
# 43647          gender
# 27741          gender
# 37325          gender
# 15382          gender
# 27323          gender
#
#                                                                                                          text  \
# 43647                                                            The strongest person in the group was a man.
# 27741                                    Lisa then balled her eyes out while telling Sir James the sad story.
# 37325  I saw a lady on the side of the road She was having trouble with her car and didn't know how to fix it
# 15382                                                           He was being such a man about going shopping.
# 27323                                                                Gary always thought of himself as a boy.
#
#                                                                                                    text_with_marker  \
# ...
